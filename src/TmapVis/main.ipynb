# %%
from PIL import Image

import matplotlib.pyplot as plt

# Open an image file
image_path = r'C:\Users\awebb\Documents\Programming\Python\MANTIS\output_images\l2r\sample_0.png'
image = Image.open(image_path)

# Display the image
plt.imshow(image)
plt.axis('off')  # Hide axes
plt.show()

# %%
import numpy as np

# Convert the image to a numpy array
image_array = np.array(image)

# %%
from matplotlib.animation import FuncAnimation

# Function to update the scatter plot
def update(t):
    ax.clear()
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.scatter(x, y, image_array[t].flatten(), c=image_array[t].flatten(), cmap='viridis')

# Create the animation
ani = FuncAnimation(fig, update, frames=range(image_array.shape[0]), interval=50)

# Display the animation
plt.show()
