# %%
scores = [2, 2, 4, 3, 2, 2, 1, 3, 4, 5, 5, 5, 4, 5, 3, 1, 2, 2, 3, 1, 1, 5, 4, 1, 5, 2, 5, 5, 3, 5, 5, 3, 1, 5]

# %%
step1 = [1, 2, 3, 5, 9, 10, 13, 14, 19, 20, 21, 22, 23, 25, 27, 28, 29, 30, 31, 32, 33, 34]
step2 = [4, 6, 7, 8, 11, 12, 15, 16, 17, 18, 24, 26]

# %%
score = 72

for i in step2:
    score -= scores[i-1]

for i in step1:
    score += scores[i-1]


score
# Out:
# 121
