# %%
from tmapmaker import TmapMaker
import numpy as np

# %%
tmapMaker = TmapMaker()

# %%
video = tmapMaker.loadVideo(r'C:\Users\awebb\Documents\Programming\Python\MANTIS\testing\ASL_Videos\Blabbermouth.mp4')

# %%
tmap = tmapMaker.processVideo(video)
# Out:
#   0%|          | 0/109 [00:00<?, ?it/s]c:\Users\awebb\Documents\Programming\Python\MANTIS\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# 100%|██████████| 109/109 [00:05<00:00, 18.76it/s]

# %%
np.array(tmap).shape
# Out:
# (109, 42, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(tmap)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.11858392506837845..0.9954033493995667].
